jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9841.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9842.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9843.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9844.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9845.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9846.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9847.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9848.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9849.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image985.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9850.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9851.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9852.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9853.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9854.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9855.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9856.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9857.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9858.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9859.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image986.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9860.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9861.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9862.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9863.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9864.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9865.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9866.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9867.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9868.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9869.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image987.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9870.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9871.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9872.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9873.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9874.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9875.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9876.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9877.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9878.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9879.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image988.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9880.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9881.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9882.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9883.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9884.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9885.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9886.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9887.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9888.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9889.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image989.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9890.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9891.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9892.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9893.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9894.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9895.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9896.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9897.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9898.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9899.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image99.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image990.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9900.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9901.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9902.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9903.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9904.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9905.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9906.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9907.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9908.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9909.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image991.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9910.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9911.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9912.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9913.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9914.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9915.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9916.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9917.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9918.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9919.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image992.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9920.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9921.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9922.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9923.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9924.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9925.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9926.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9927.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9928.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9929.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image993.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9930.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9931.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9932.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9933.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9934.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9935.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9936.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9937.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9938.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9939.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image994.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9940.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9941.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9942.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9943.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9944.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9945.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9946.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9947.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9948.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9949.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image995.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9950.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9951.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9952.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9953.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9954.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9955.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9956.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9957.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9958.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9959.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image996.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9960.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9961.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9962.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9963.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9964.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9965.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9966.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9967.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9968.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9969.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image997.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9970.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9971.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9972.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9973.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9974.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9975.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9976.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9977.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9978.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9979.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image998.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9980.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9981.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9982.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9983.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9984.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9985.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9986.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9987.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9988.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9989.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image999.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9990.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9991.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9992.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9993.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9994.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9995.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9996.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9997.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9998.jpeg
#   inflating: /content/oct data/NORMAL_border_remove/image9999.jpeg
#
# done!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout 
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import classification_report,confusion_matrix

import tensorflow as tf

import cv2
import os

import numpy as np

# %%
labels = ["CNV_border_remove", "DME_border_remove", "Drusen_border_remove","NORMAL_border_remove"]
img_size = 32
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img))[...,::-1] #convert BGR to RGB format
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
train = get_data("/content/oct data")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   from ipykernel import kernelapp as app

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("CNV_border_remove")
    elif(i[1] == 1):
          l.append("DME_border_remove")
    elif(i[1] == 2):
          l.append("Drusen_border_remove")
    elif(i[1] == 3):
          l.append("NORMAL_border_remove")

            
       
sns.set_style('darkgrid')
sns.countplot(l)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[1][0])
plt.title(labels[train[0][1]])
# Out:
# Text(0.5, 1.0, 'CNV_border_remove')

# %%
x_train = []
y_train = []


for feature, label in train:
  x_train.append(feature)
  y_train.append(label)
x_train = np.array(x_train) / 255
x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

# %%
# split with a stratified sampling
from sklearn.model_selection import train_test_split
(x_train, x_test, y_train, y_test) = train_test_split(x_train, y_train,
    test_size=0.15, stratify=y_train, random_state=42)

# %%
# !pip install -U -q tensorflow-addons
# Out:
#      |████████████████████████████████| 1.1 MB 29.9 MB/s

# %%
from tensorflow.keras import layers
from tensorflow import keras

import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np

# %%
y_train = keras.utils.to_categorical(
    y_train, num_classes=4, dtype='float32'
)
y_test = keras.utils.to_categorical(
    y_test, num_classes=4, dtype='float32'
)

# %%
positional_emb = True
conv_layers = 2
projection_dim = 128

num_heads = 2
transformer_units = [
    projection_dim,
    projection_dim,
]
transformer_layers = 1
stochastic_depth_rate = 0.1

learning_rate = 0.001
weight_decay = 0.0001
batch_size = 128
num_epochs = 100
image_size = 32

# %%
num_classes = 4
input_shape = (32, 32, 3)

# %%
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
# Out:
# x_train shape: (92912, 32, 32, 3) - y_train shape: (92912, 4)
# x_test shape: (16397, 32, 32, 3) - y_test shape: (16397, 4)

# %%
class CCTTokenizer(layers.Layer):
    def __init__(
        self,
        kernel_size=3,
        stride=1,
        padding=1,
        pooling_kernel_size=3,
        pooling_stride=2,
        num_conv_layers=conv_layers,
        num_output_channels=[64, 128],
        positional_emb=positional_emb,
        **kwargs,
    ):
        super(CCTTokenizer, self).__init__(**kwargs)

        # This is our tokenizer.
        self.conv_model = keras.Sequential()
        for i in range(num_conv_layers):
            self.conv_model.add(
                layers.Conv2D(
                    num_output_channels[i],
                    kernel_size,
                    stride,
                    padding="valid",
                    use_bias=False,
                    activation="relu",
                    kernel_initializer="he_normal",
                )
            )
            self.conv_model.add(layers.ZeroPadding2D(padding))
            self.conv_model.add(
                layers.MaxPool2D(pooling_kernel_size, pooling_stride, "same")
            )

        self.positional_emb = positional_emb

    def call(self, images):
        outputs = self.conv_model(images)
        # After passing the images through our mini-network the spatial dimensions
        # are flattened to form sequences.
        reshaped = tf.reshape(
            outputs,
            (-1, tf.shape(outputs)[1] * tf.shape(outputs)[2], tf.shape(outputs)[-1]),
        )
        return reshaped

    def positional_embedding(self, image_size):
        # Positional embeddings are optional in CCT. Here, we calculate
        # the number of sequences and initialize an `Embedding` layer to
        # compute the positional embeddings later.
        if self.positional_emb:
            dummy_inputs = tf.ones((1, image_size, image_size, 3))
            dummy_outputs = self.call(dummy_inputs)
            sequence_length = tf.shape(dummy_outputs)[1]
            projection_dim = tf.shape(dummy_outputs)[-1]

            embed_layer = layers.Embedding(
                input_dim=sequence_length, output_dim=projection_dim
            )
            return embed_layer, sequence_length
        else:
            return None

# %%
# Referred from: github.com:rwightman/pytorch-image-models.
class StochasticDepth(layers.Layer):
    def __init__(self, drop_prop, **kwargs):
        super(StochasticDepth, self).__init__(**kwargs)
        self.drop_prob = drop_prop

    def call(self, x, training=None):
        if training:
            keep_prob = 1 - self.drop_prob
            shape = (tf.shape(x)[0],) + (1,) * (len(tf.shape(x)) - 1)
            random_tensor = keep_prob + tf.random.uniform(shape, 0, 1)
            random_tensor = tf.floor(random_tensor)
            return (x / keep_prob) * random_tensor
        return x

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
# Note the rescaling layer. These layers have pre-defined inference behavior.
data_augmentation = keras.Sequential(
    [
        layers.Rescaling(scale=1.0 / 255),
        layers.RandomCrop(image_size, image_size),
        layers.RandomFlip("horizontal"),
    ],
    name="data_augmentation",
)

# %%
def create_cct_model(
    image_size=image_size,
    input_shape=input_shape,
    num_heads=num_heads,
    projection_dim=projection_dim,
    transformer_units=transformer_units,
):

    inputs = layers.Input(input_shape)

    # Augment data.
    augmented = data_augmentation(inputs)

    # Encode patches.
    cct_tokenizer = CCTTokenizer()
    encoded_patches = cct_tokenizer(augmented)

    # Apply positional embedding.
    if positional_emb:
        pos_embed, seq_length = cct_tokenizer.positional_embedding(image_size)
        positions = tf.range(start=0, limit=seq_length, delta=1)
        position_embeddings = pos_embed(positions)
        encoded_patches += position_embeddings

    # Calculate Stochastic Depth probabilities.
    dpr = [x for x in np.linspace(0, stochastic_depth_rate, transformer_layers)]

    # Create multiple layers of the Transformer block.
    for i in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)

        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)

        # Skip connection 1.
        attention_output = StochasticDepth(dpr[i])(attention_output)
        x2 = layers.Add()([attention_output, encoded_patches])

        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-5)(x2)

        # MLP.
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)

        # Skip connection 2.
        x3 = StochasticDepth(dpr[i])(x3)
        encoded_patches = layers.Add()([x3, x2])

    # Apply sequence pooling.
    representation = layers.LayerNormalization(epsilon=1e-5)(encoded_patches)
    attention_weights = tf.nn.softmax(layers.Dense(1)(representation), axis=1)
    weighted_representation = tf.matmul(
        attention_weights, representation, transpose_a=True
    )
    weighted_representation = tf.squeeze(weighted_representation, -2)

    # Classify outputs.
    logits = layers.Dense(num_classes)(weighted_representation)
    # Create the Keras model.
    model = keras.Model(inputs=inputs, outputs=logits)
    model.summary()
    return model

# %%
def run_experiment(model):
    optimizer = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=False,
    name="Adam"
)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.CategoricalCrossentropy(
            from_logits=True, label_smoothing=0.1
        ),
        metrics=[
            keras.metrics.CategoricalAccuracy(name="accuracy"),
            keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/content/cct_model_h5/model.h5"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.15,
        callbacks=[checkpoint_callback]
    )

    model.load_weights(checkpoint_filepath)
    _, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
    from sklearn.metrics import classification_report, confusion_matrix



    # as I've trained my model on MNIST as odd or even (binary classes)
    target_names = ["CNV_border_remove", "DME_border_remove", "Drusen_border_remove","NORMAL_border_remove"]


    # get predict prob and label 
    ypred = model.predict(x_test, verbose=1)
    ypred = np.argmax(ypred, axis=1)
    print(classification_report(np.argmax(y_test, axis=1), ypred, target_names=target_names))
    import matplotlib.pyplot as plt
    import seaborn as sns
    import pandas as pd 

    cm = confusion_matrix(np.argmax(y_test, axis=1), ypred)
    cm = pd.DataFrame(cm, range(4),range(4))
    plt.figure(figsize = (10,10))

    sns.heatmap(cm, annot=True, annot_kws={"size": 12}) # font size
    plt.show()
    return history


cct_model = create_cct_model()
history = run_experiment(cct_model)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  data_augmentation (Sequential)  (None, 32, 32, 3)   0           ['input_3[0][0]']
#
#  cct_tokenizer_2 (CCTTokenizer)  (None, 64, 128)     75456       ['data_augmentation[2][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 64, 128)     0           ['cct_tokenizer_2[0][0]']
#  mbda)
#
#  layer_normalization_6 (LayerNo  (None, 64, 128)     256         ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 64, 128)     131968      ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  stochastic_depth_4 (Stochastic  (None, 64, 128)     0           ['multi_head_attention_2[0][0]']
#  Depth)
#
#  add_4 (Add)                    (None, 64, 128)      0           ['stochastic_depth_4[0][0]',
#                                                                   'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 64, 128)     256         ['add_4[0][0]']
#  rmalization)
#
#  dense_8 (Dense)                (None, 64, 128)      16512       ['layer_normalization_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 64, 128)      0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 64, 128)      16512       ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 64, 128)      0           ['dense_9[0][0]']
#
#  stochastic_depth_5 (Stochastic  (None, 64, 128)     0           ['dropout_5[0][0]']
#  Depth)
#
#  add_5 (Add)                    (None, 64, 128)      0           ['stochastic_depth_5[0][0]',
#                                                                   'add_4[0][0]']
#
#  layer_normalization_8 (LayerNo  (None, 64, 128)     256         ['add_5[0][0]']
#  rmalization)
#
#  dense_10 (Dense)               (None, 64, 1)        129         ['layer_normalization_8[0][0]']
#
#  tf.nn.softmax_2 (TFOpLambda)   (None, 64, 1)        0           ['dense_10[0][0]']
#
#  tf.linalg.matmul_2 (TFOpLambda  (None, 1, 128)      0           ['tf.nn.softmax_2[0][0]',
#  )                                                                'layer_normalization_8[0][0]']
#
#  tf.compat.v1.squeeze_2 (TFOpLa  (None, 128)         0           ['tf.linalg.matmul_2[0][0]']
#  mbda)
#
#  dense_11 (Dense)               (None, 4)            516         ['tf.compat.v1.squeeze_2[0][0]']
#
# ==================================================================================================
# Total params: 241,861
# Trainable params: 241,861
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 617/617 [==============================] - 20s 27ms/step - loss: 0.9877 - accuracy: 0.6695 - top-5-accuracy: 1.0000 - val_loss: 0.8578 - val_accuracy: 0.7442 - val_top-5-accuracy: 1.0000
# Epoch 2/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.7998 - accuracy: 0.7740 - top-5-accuracy: 1.0000 - val_loss: 0.7648 - val_accuracy: 0.8015 - val_top-5-accuracy: 1.0000
# Epoch 3/100
# 617/617 [==============================] - 15s 25ms/step - loss: 0.7440 - accuracy: 0.8044 - top-5-accuracy: 1.0000 - val_loss: 0.7719 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 4/100
# 617/617 [==============================] - 15s 25ms/step - loss: 0.7145 - accuracy: 0.8177 - top-5-accuracy: 1.0000 - val_loss: 0.7399 - val_accuracy: 0.8147 - val_top-5-accuracy: 1.0000
# Epoch 5/100
# 617/617 [==============================] - 16s 26ms/step - loss: 0.4811 - accuracy: 0.9368 - top-5-accuracy: 1.0000 - val_loss: 0.5473 - val_accuracy: 0.9073 - val_top-5-accuracy: 1.0000
# Epoch 91/100
# 617/617 [==============================] - 16s 26ms/step - loss: 0.4832 - accuracy: 0.9355 - top-5-accuracy: 1.0000 - val_loss: 0.5440 - val_accuracy: 0.9094 - val_top-5-accuracy: 1.0000
# Epoch 92/100
# 617/617 [==============================] - 16s 26ms/step - loss: 0.4810 - accuracy: 0.9369 - top-5-accuracy: 1.0000 - val_loss: 0.5454 - val_accuracy: 0.9091 - val_top-5-accuracy: 1.0000
# Epoch 93/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.4807 - accuracy: 0.9369 - top-5-accuracy: 1.0000 - val_loss: 0.5427 - val_accuracy: 0.9086 - val_top-5-accuracy: 1.0000
# Epoch 94/100
# 617/617 [==============================] - 16s 26ms/step - loss: 0.4791 - accuracy: 0.9384 - top-5-accuracy: 1.0000 - val_loss: 0.5500 - val_accuracy: 0.9067 - val_top-5-accuracy: 1.0000
# Epoch 95/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.4793 - accuracy: 0.9378 - top-5-accuracy: 1.0000 - val_loss: 0.5457 - val_accuracy: 0.9089 - val_top-5-accuracy: 1.0000
# Epoch 96/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.4785 - accuracy: 0.9387 - top-5-accuracy: 1.0000 - val_loss: 0.5628 - val_accuracy: 0.8987 - val_top-5-accuracy: 1.0000
# Epoch 97/100
# 617/617 [==============================] - 16s 26ms/step - loss: 0.4794 - accuracy: 0.9373 - top-5-accuracy: 1.0000 - val_loss: 0.5416 - val_accuracy: 0.9105 - val_top-5-accuracy: 1.0000
# Epoch 98/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.4741 - accuracy: 0.9409 - top-5-accuracy: 1.0000 - val_loss: 0.5436 - val_accuracy: 0.9107 - val_top-5-accuracy: 1.0000
# Epoch 99/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.4758 - accuracy: 0.9403 - top-5-accuracy: 1.0000 - val_loss: 0.5714 - val_accuracy: 0.9026 - val_top-5-accuracy: 1.0000
# Epoch 100/100
# 617/617 [==============================] - 16s 25ms/step - loss: 0.4754 - accuracy: 0.9399 - top-5-accuracy: 1.0000 - val_loss: 0.5513 - val_accuracy: 0.9081 - val_top-5-accuracy: 1.0000
# 513/513 [==============================] - 4s 8ms/step - loss: 0.5423 - accuracy: 0.9149 - top-5-accuracy: 1.0000
# Test accuracy: 91.49%
# Test top 5 accuracy: 100.0%
# 513/513 [==============================] - 4s 6ms/step
#                       precision    recall  f1-score   support
#
#    CNV_border_remove       0.94      0.94      0.94      5618
#    DME_border_remove       0.90      0.84      0.87      1740
# Drusen_border_remove       0.74      0.54      0.62      1330
# NORMAL_border_remove       0.92      0.98      0.95      7709
#
#             accuracy                           0.91     16397
#            macro avg       0.88      0.82      0.85     16397
#         weighted avg       0.91      0.91      0.91     16397

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.plot(history.history["accuracy"], label="train_accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("accuracy")
plt.title("Train and Validation accuracy Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()
